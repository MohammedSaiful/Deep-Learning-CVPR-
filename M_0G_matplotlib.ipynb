# %% [markdown]
# # Plotting graphs with Matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]
print(x)
print(y)
# Out:
# [1, 2, 3, 4, 5, 6, 7]
# [50, 51, 52, 48, 47, 49, 46]

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y)

# %%
plt.plot(x,y, color='green')

# %%
plt.plot(x,y, color='red', linewidth=7)

# %%
plt.plot(x,y, color='green', linewidth=5, linestyle='dotted')

# %%
plt.plot(x,y,'b+--')

# %%
plt.plot(x,y,color='blue',marker='+',linestyle='')

# %%
plt.plot(x,y,color='blue',marker='+',linestyle='',markersize=20)

# %%
plt.plot(x,y,'g<',alpha=0.5) # alpha can be specified on a scale 0 to 1

# %%
import numpy as np

# %%
# First create some toy data:
x = np.arange(-10, 10, 0.1)
y1 = np.sin(x)
y2 = np.cos(x)

# %%
plt.figure()
plt.plot(x,y1)
plt.plot(x,y2)
plt.legend(['Sine','Cosine'])
plt.show()

# %%
plt.figure()
plt.plot(x,y1,x,y2)
plt.legend(['Sine','Cosine'])
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
plt.plot(x,y1)
plt.title('Sine')
plt.subplot(1,2,2)
plt.plot(x,y2)
plt.title('Cosine')
plt.show()

# %%
from IPython import display

# %%
sin =[]
X = []

plt.figure()
for i in range(-50,50,1):
    X.append(i)
    sin.append(np.sin(i))
    display.clear_output(wait=True)
    plt.plot(X,sin)
    plt.show()

# %%
fig = plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
plt.plot(x,y1)
plt.title('Sine')
plt.subplot(1,2,2)
plt.plot(x,y2)
plt.title('Cosine')
plt.savefig('test.pdf', transparent=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2279615489.py in <cell line: 0>()
#       6 plt.plot(x,y2)
#       7 plt.title('Cosine')
# ----> 8 plt.savefig('test.pdf', transparent=True)
#       9 plt.show()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#    1241     # savefig default implementation has no return, so mypy is unhappy
#    1242     # presumably this is here because subclasses can return?
# -> 1243     res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1244     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1245     return res
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3488                 for ax in self.axes:
#    3489                     _recursively_make_axes_transparent(stack, ax)
# -> 3490             self.canvas.print_figure(fname, **kwargs)
#    3491
#    3492     def ginput(self, n=1, timeout=30, show_clicks=True,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2123         # Remove the figure manager, if any, to avoid resizing the GUI widget.
#    2124         with (cbook._setattr_cm(self, manager=None),
# -> 2125               self._switch_canvas_and_return_print_method(format, backend)
#    2126                  as print_method,
#    2127               cbook._setattr_cm(self.figure, dpi=dpi),
#
# /usr/lib/python3.12/contextlib.py in __enter__(self)
#     135         del self.args, self.kwds, self.func
#     136         try:
# --> 137             return next(self.gen)
#     138         except StopIteration:
#     139             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/backend_bases.py in _switch_canvas_and_return_print_method(self, fmt, backend)
#    2022         else:
#    2023             # Return a default canvas for the requested format, if it exists.
# -> 2024             canvas_class = get_registered_canvas_class(fmt)
#    2025             if canvas_class is None:
#    2026                 raise ValueError(
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/backend_bases.py in get_registered_canvas_class(format)
#     123     backend_class = _default_backends[format]
#     124     if isinstance(backend_class, str):
# --> 125         backend_class = importlib.import_module(backend_class).FigureCanvas
#     126         _default_backends[format] = backend_class
#     127     return backend_class
#
# /usr/lib/python3.12/importlib/__init__.py in import_module(name, package)
#      88                 break
#      89             level += 1
# ---> 90     return _bootstrap._gcd_import(name[level:], package, level)
#      91
#      92
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.12/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/backends/backend_pdf.py in <module>
#      41 from matplotlib.dates import UTC
#      42 from matplotlib import _path
# ---> 43 from . import _backend_pdf_ps
#      44
#      45 _log = logging.getLogger(__name__)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/backends/_backend_pdf_ps.py in <module>
#       7 import logging
#       8
# ----> 9 from fontTools import subset
#      10
#      11 import matplotlib as mpl
#
# /usr/local/lib/python3.12/dist-packages/fontTools/subset/__init__.py in <module>
#       8 from fontTools.misc.roundTools import otRound
#       9 from fontTools import ttLib
# ---> 10 from fontTools.ttLib.tables import otTables
#      11 from fontTools.ttLib.tables.otBase import USE_HARFBUZZ_REPACKER
#      12 from fontTools.otlLib.maxContextCalc import maxCtxFont
#
# KeyboardInterrupt:
